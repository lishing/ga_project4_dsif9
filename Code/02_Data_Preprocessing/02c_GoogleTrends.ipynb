# %%
# import the usual libraries
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns

# for cleaning
import datetime

# %%
# read in file of dengue cases with trends
trends = pd.read_csv('../../assets/google_trends.csv')

# %%
trends.head()
# Out:
#       Week  dengue: (Singapore)  dengue fever: (Singapore)  \
# 0   5/1/14                   44                         52
# 1  12/1/14                   38                         53
# 2  19/1/14                   31                         60
# 3  26/1/14                   23                         24
# 4   2/2/14                   28                         44
#
#    rashes: (Singapore)  vomiting: (Singapore)  eye pain: (Singapore)  \
# 0                   67                     43                     30
# 1                   73                     38                      0
# 2                   60                     52                     12
# 3                   57                     39                     31
# 4                   56                     31                      0
#
#    joint pain: (Singapore)  fever: (Singapore)  Wolbachia: (Singapore)  \
# 0                       27                  73                       0
# 1                       26                  66                       2
# 2                       13                  80                       0
# 3                        0                  64                       0
# 4                        7                  72                       0
#
#    headache: (Singapore)  nausea: (Singapore)  Fogging: (Singapore)  \
# 0                     22                    9                     0
# 1                     25                   11                     0
# 2                     27                    8                     0
# 3                     25                   12                     0
# 4                     22                    8                     0
#
#    Insect repellent: (Singapore) Insecticide: (Singapore)
# 0                              1                        1
# 1                              3                        2
# 2                              3                        0
# 3                              3                        1
# 4                              3                        0

# %%
# check format of series
trends.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 261 entries, 0 to 260
# Data columns (total 14 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Week                           261 non-null    object
#  1   dengue: (Singapore)            261 non-null    int64
#  2   dengue fever: (Singapore)      261 non-null    int64
#  3   rashes: (Singapore)            261 non-null    int64
#  4   vomiting: (Singapore)          261 non-null    int64
#  5   eye pain: (Singapore)          261 non-null    int64
#  6   joint pain: (Singapore)        261 non-null    int64
#  7   fever: (Singapore)             261 non-null    int64
#  8   Wolbachia: (Singapore)         261 non-null    int64
#  9   headache: (Singapore)          261 non-null    int64
#  10  nausea: (Singapore)            261 non-null    int64
#  11  Fogging: (Singapore)           261 non-null    int64
#  12  Insect repellent: (Singapore)  261 non-null    int64
#  13  Insecticide: (Singapore)       261 non-null    object
# dtypes: int64(12), object(2)
# memory usage: 28.7+ KB

# %%
# convert to datetime format
trends['date']=pd.to_datetime(trends['Week'], format='%d/%m/%y')

# split into year, month, and week
trends['year'] = trends['date'].dt.year
trends['month'] = trends['date'].dt.month
trends['week'] = trends['date'].dt.week # convert to weeks 1 to 52
# Out:
# /var/folders/t4/n89gfp4s10b4j476kq4xh2p00000gn/T/ipykernel_44385/126485608.py:7: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated. Please use Series.dt.isocalendar().week instead.
#   trends['week'] = trends['date'].dt.week # convert to weeks 1 to 52

# %%
# check the data
trends.head()
# Out:
#       Week  dengue: (Singapore)  dengue fever: (Singapore)  \
# 0   5/1/14                   44                         52
# 1  12/1/14                   38                         53
# 2  19/1/14                   31                         60
# 3  26/1/14                   23                         24
# 4   2/2/14                   28                         44
#
#    rashes: (Singapore)  vomiting: (Singapore)  eye pain: (Singapore)  \
# 0                   67                     43                     30
# 1                   73                     38                      0
# 2                   60                     52                     12
# 3                   57                     39                     31
# 4                   56                     31                      0
#
#    joint pain: (Singapore)  fever: (Singapore)  Wolbachia: (Singapore)  \
# 0                       27                  73                       0
# 1                       26                  66                       2
# 2                       13                  80                       0
# 3                        0                  64                       0
# 4                        7                  72                       0
#
#    headache: (Singapore)  nausea: (Singapore)  Fogging: (Singapore)  \
# 0                     22                    9                     0
# 1                     25                   11                     0
# 2                     27                    8                     0
# 3                     25                   12                     0
# 4                     22                    8                     0
#
#    Insect repellent: (Singapore) Insecticide: (Singapore)       date  year  \
# 0                              1                        1 2014-01-05  2014
# 1                              3                        2 2014-01-12  2014
# 2                              3                        0 2014-01-19  2014
# 3                              3                        1 2014-01-26  2014
# 4                              3                        0 2014-02-02  2014
#
#    month  week
# 0      1     1
# 1      1     2
# 2      1     3
# 3      1     4
# 4      2     5

# %%
trends.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 261 entries, 0 to 260
# Data columns (total 18 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Week                           261 non-null    object
#  1   dengue: (Singapore)            261 non-null    int64
#  2   dengue fever: (Singapore)      261 non-null    int64
#  3   rashes: (Singapore)            261 non-null    int64
#  4   vomiting: (Singapore)          261 non-null    int64
#  5   eye pain: (Singapore)          261 non-null    int64
#  6   joint pain: (Singapore)        261 non-null    int64
#  7   fever: (Singapore)             261 non-null    int64
#  8   Wolbachia: (Singapore)         261 non-null    int64
#  9   headache: (Singapore)          261 non-null    int64
#  10  nausea: (Singapore)            261 non-null    int64
#  11  Fogging: (Singapore)           261 non-null    int64
#  12  Insect repellent: (Singapore)  261 non-null    int64
#  13  Insecticide: (Singapore)       261 non-null    object
#  14  date                           261 non-null    datetime64[ns]
#  15  year                           261 non-null    int64
#  16  month                          261 non-null    int64
#  17  week                           261 non-null    int64
# dtypes: datetime64[ns](1), int64(15), object(2)
# memory usage: 36.8+ KB

# %%
# rename the columns
new_columns_dict = {
    'dengue: (Singapore)': 'dengue_search',
    'dengue fever: (Singapore)': 'dengue_fever_search',
    'rashes: (Singapore)': 'rashes_search',
    'vomiting: (Singapore)': 'vomiting_search',
    'eye pain: (Singapore)': 'eye_pain_search',
    'joint pain: (Singapore)': 'joint_pain_search',
    'fever: (Singapore)': 'fever_search',
    'Wolbachia: (Singapore)': 'wolbachia_search',
    'headache: (Singapore)': 'headache_search',
    'nausea: (Singapore)': 'nausea_search',
    'Fogging: (Singapore)': 'fogging_search',
    'Insect repellent: (Singapore)': 'insect_repellent_search',
    'Insecticide: (Singapore)' : 'insecticide_search'
}

# assign new column names
trends.rename(columns = new_columns_dict, inplace=True)

# %%
# reassign the column names
trends_columns = ['date', 'year', 'month', 'week', 'dengue_search', 'dengue_fever_search', 
                  'rashes_search', 'vomiting_search', 'eye_pain_search', 'joint_pain_search',
                 'fever_search', 'wolbachia_search', 'headache_search', 'nausea_search', 'fogging_search',
                 'insect_repellent_search','insecticide_search']

trends = trends[trends_columns]

# %%
# check if all headers are aligned
trends.head()
# Out:
#         date  year  month  week  dengue_search  dengue_fever_search  \
# 0 2014-01-05  2014      1     1             44                   52
# 1 2014-01-12  2014      1     2             38                   53
# 2 2014-01-19  2014      1     3             31                   60
# 3 2014-01-26  2014      1     4             23                   24
# 4 2014-02-02  2014      2     5             28                   44
#
#    rashes_search  vomiting_search  eye_pain_search  joint_pain_search  \
# 0             67               43               30                 27
# 1             73               38                0                 26
# 2             60               52               12                 13
# 3             57               39               31                  0
# 4             56               31                0                  7
#
#    fever_search  wolbachia_search  headache_search  nausea_search  \
# 0            73                 0               22              9
# 1            66                 2               25             11
# 2            80                 0               27              8
# 3            64                 0               25             12
# 4            72                 0               22              8
#
#    fogging_search  insect_repellent_search insecticide_search
# 0               0                        1                  1
# 1               0                        3                  2
# 2               0                        3                  0
# 3               0                        3                  1
# 4               0                        3                  0

# %%
trends.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 261 entries, 0 to 260
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   date                     261 non-null    datetime64[ns]
#  1   year                     261 non-null    int64
#  2   month                    261 non-null    int64
#  3   week                     261 non-null    int64
#  4   dengue_search            261 non-null    int64
#  5   dengue_fever_search      261 non-null    int64
#  6   rashes_search            261 non-null    int64
#  7   vomiting_search          261 non-null    int64
#  8   eye_pain_search          261 non-null    int64
#  9   joint_pain_search        261 non-null    int64
#  10  fever_search             261 non-null    int64
#  11  wolbachia_search         261 non-null    int64
#  12  headache_search          261 non-null    int64
#  13  nausea_search            261 non-null    int64
#  14  fogging_search           261 non-null    int64
#  15  insect_repellent_search  261 non-null    int64
#  16  insecticide_search       261 non-null    object
# dtypes: datetime64[ns](1), int64(15), object(1)
# memory usage: 34.8+ KB

# %%
# Define a function to add one day to a datetime object
def add_one_day(date):
    new_date = date + datetime.timedelta(days=1)
    new_date = new_date.strftime('%Y-%d-%m')
    return new_date

# %%
# Apply the function to the 'date' column
trends['date'] = trends['date'].apply(add_one_day)

# %%
trends.head(10)
# Out:
#          date  year  month  week  dengue_search  dengue_fever_search  \
# 0  2014-06-01  2014      1     1             44                   52
# 1  2014-13-01  2014      1     2             38                   53
# 2  2014-20-01  2014      1     3             31                   60
# 3  2014-27-01  2014      1     4             23                   24
# 4  2014-03-02  2014      2     5             28                   44
# 5  2014-10-02  2014      2     6             35                   45
# 6  2014-17-02  2014      2     7             28                   31
# 7  2014-24-02  2014      2     8             34                   59
# 8  2014-03-03  2014      3     9             31                   54
# 9  2014-10-03  2014      3    10             18                   28
#
#    rashes_search  vomiting_search  eye_pain_search  joint_pain_search  \
# 0             67               43               30                 27
# 1             73               38                0                 26
# 2             60               52               12                 13
# 3             57               39               31                  0
# 4             56               31                0                  7
# 5             75               56                0                 10
# 6             55               34                7                 12
# 7             40               21                0                 23
# 8             42               30               10                 14
# 9             62               39                0                 18
#
#    fever_search  wolbachia_search  headache_search  nausea_search  \
# 0            73                 0               22              9
# 1            66                 2               25             11
# 2            80                 0               27              8
# 3            64                 0               25             12
# 4            72                 0               22              8
# 5            58                 0               24             15
# 6            59                 0               25             11
# 7            73                 0               28              7
# 8            56                 2               20             10
# 9            48                 0               14             13
#
#    fogging_search  insect_repellent_search insecticide_search
# 0               0                        1                  1
# 1               0                        3                  2
# 2               0                        3                  0
# 3               0                        3                  1
# 4               0                        3                  0
# 5               0                        3                  0
# 6              39                        4                  0
# 7              18                        6                  1
# 8              28                        9                  0
# 9               0                        6                  1

# %%
# export the trends dataframe into a .csv file
trends.to_csv('../../assets/complete_google_trends.csv')
